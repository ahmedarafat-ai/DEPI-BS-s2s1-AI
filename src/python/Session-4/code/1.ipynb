# %%
def function_2(*name):
    print(name)
    print(type(name))

# %%
fuction_2("welcome", "Depi", "machine learning", 20, 30, 40, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fuction_2("welcome", "Depi", "machine learning", 20, 30, 40, True)
#
# NameError: name 'fuction_2' is not defined

# %%
lst_1 = [10, 2, 30, 4]
x = lst_1.sort()
print(x)
print(lst_1)

# %%
x = sorted(lst_1)
print(x)

# %%
def fuc_1(*name):
    print(name)
    print(type(name))

# %%
fuc_1("hello", "depi", 222, 2.9, True)

# %%
print("my name is ahmed and my age is 40".format(name, age))

# %%
def fuc_2(**name):
    print(name)
    print(type(name))

# %%
func_2(name="ahmed", age=21, city="cairo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 func_2(name="ahmed", age=21, city="cairo")
#
# NameError: name 'func_2' is not defined

# %%
fun_11=lambda x: x+10
type(fun_11)
# Out:
# function

# %%
for i in range(10):
    lambda i : i*100

# %%
xy = lambda x,y,z : x+y+z
print()

# %%
def fuc_33(n):
    return lambda a: a * n

# %%
x = fuc_33(2)
print(x(11))
# Out:
# 22

# %%
num = 5
result = 1

for i in range(1, num + 1):
    result *= i
print(result)
# Out:
# 120

# %%
def factorial(num):
    if num == 0 or num == 1:
        return 1
    return num * factorial(num - 1)

# %%
factorial(0)
# Out:
# 1

# %%
from math saga import factorial

# %%
for i in range(2,10):
    if 10 % i == 0:
        print ( "False")
print("true")
# Out:
# False
# False
# true

# %%
def common_divisors(num1:int, num2: int) -> list[int]:
    limit=min(num1,num2)
    divisors=[]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 is_prime(10)
#
# NameError: name 'is_prime' is not defined

# %%
s = "Ahmed Arafat"
lst = s.split(" ")
print(lst)
new_list = lst[::-1]
print(new_list)
# Out:
# ['Ahmed', 'Arafat']
# ['Arafat', 'Ahmed']

# %%
import random

char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
password = ""
pass_length = 8

for _ in range(pass_length):
    password += random.choice(char)
print(password)
# Out:
# m3BqFY4F

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
counts = {word: 0 for word in unique_words}

print(counts)
# Out:
# {'No': 0, 'Welcome': 0, 'Ali': 0, 'Hi': 0}

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
counts = {word: 0 for word in unique_words}
for i in unique_words:
    for j in words:
        if i == j:
            counts[i] += 1
counts
# Out:
# {'No': 3, 'Welcome': 1, 'Ali': 4, 'Hi': 2}
