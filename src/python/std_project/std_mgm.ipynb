# %%
class Student:
    _id_counter = 1  # class attribute

    def __init__(self, name):
        self.student_id = Student._id_counter
        Student._id_counter += 1
        self.name = name
        self.grades = {}
        self.enrolled_courses = []

    def __str__(self):
        return f"student ID :{self.student_id} name :{self.name}, Grades :{self.grades}, Courses :{self.enrolled_courses}"

    def __repr__(self) -> str:
        return f"student ID :{self.student_id} name :{self.name}, Grades :{self.grades}, Courses :{self.enrolled_courses}"

    def add_grade(self, course_id, grade):
        if not (0 <= grade <= 100):
            raise ValueError("grade must be between 0 and 100")
        self.grades[course_id] = grade

    def enroll_in_course(self, course):
        if course in self.enrolled_courses:
            raise ValueError("Student already enrolled in this course")
        else:
            self.enrolled_courses.append(course)

# %%
s1 = Student("ahmed")
repr(s1)
s1.add_grade(1, 90)
str(s1)
s1.enroll_in_course(3)
str(s1)
# Out:
# 'student ID :1 name :ahmed, Grades :{1: 90}, Courses :[3]'

# %%
class Course:
    _id_counter = 1  # class attribute

    def __init__(self, name):
        self.course_id = Course._id_counter
        Course._id_counter += 1
        self.name = name
        self.enrolled_students = []

# %%
import

class Course:
    _id_counter = 1  # class attribute

    def __init__(self, name):
        self.course_id = Course._id_counter
        Course._id_counter += 1
        self.name = name
        self.enrolled_students = []

# %%
import unittest


class TestStudent(unittest.TestCase):
    def setUp(self):  
        self.student = Student("Faris")

    def test_creation(self):
        self.assertEqual(self.student.name, "Faris")

    def test_add_grade(self):
        self.student.add_grade(1, 90)
        self.assertEqual(self.student.grades[1], 90)

    def test_enroll_in_course(self):
        course = Course("Math")
        self.student.enroll_in_course(course)
        self.assertIn(course, self.student.enrolled_courses)


unittest.main(argv=["first-arg-is-ignored"], exit=False)
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.006s
#
# OK

# %%
import unittest


class TestCourse(unittest.TestCase):

    def setUp(self):
        self.course = Course("Math")
        self.student = Student("Faris")

    def test_course_creation(self):
        self.assertEqual(self.course.name, "Math")
        self.assertEqual(len(self.course.enrolled_students), 0)

    def test_enroll_student(self):
        self.course.enroll_student(self.student)
        self.assertIn(self.student, self.course.enrolled_students)

    def test_remove_student(self):
        self.course.enroll_student(self.student)
        self.course.remove_student(self.student)
        self.assertNotIn(self.student, self.course.enrolled_students)


# تشغيل الاختبارات
unittest.main(argv=["first-arg-is-ignored"], exit=False)
# Out:
# .EE...
# ======================================================================
# ERROR: test_enroll_student (__main__.TestCourse.test_enroll_student)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Ahmed\AppData\Local\Temp\ipykernel_2768\1413179703.py", line 15, in test_enroll_student
#     self.course.enroll_student(self.student)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Course' object has no attribute 'enroll_student'. Did you mean: 'enrolled_students'?
#
# ======================================================================
# ERROR: test_remove_student (__main__.TestCourse.test_remove_student)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Ahmed\AppData\Local\Temp\ipykernel_2768\1413179703.py", line 19, in test_remove_student
#     self.course.enroll_student(self.student)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Course' object has no attribute 'enroll_student'. Did you mean: 'enrolled_students'?
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.012s
#
# FAILED (errors=2)
