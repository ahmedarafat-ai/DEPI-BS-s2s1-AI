# %%
list_one =[1,2,3,4,"Depi","machine learning",True,[1,2,3,"true",["ml","dl","llm"]]]
print(type(list_one))
# Out:
# <class 'list'>

# %%
list_one[7][4][0]="DS"

# %%
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Depi',
#  'machine learning',
#  True,
#  [1, 2, 3, 'true', ['DS', 'dl', 'llm']]]

# %%
ahmed=list("amit")
print(ahmed)
# Out:
# ['a', 'm', 'i', 't']

# %%
list_1=["Depi","ml","genai"]
list_1.append("Deep learning")
print(list_1)
# Out:
# ['Depi', 'ml', 'genai', 'Deep learning']

# %%
list_1.insert(0,"NLP")

# %%
list_1.extend("Ahmed")
list_1
# Out:
# ['NLP', 'Depi', 'ml', 'genai', 'Deep learning', 'A', 'h', 'm', 'e', 'd']

# %%
new_list=["NLP",'Depi','ml','genai',"Depi",'Deep learning','A','h','m','e','d']

# %%
new_list

# %%
list_2=["depi","ml","ai"]
list_2.pop()
# Out:
# 'ai'

# %%
list_2
# Out:
# ['depi', 'ml']

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print(f"My name is {name}, and my age is {age}")
# Out:
# My name is , and my age is python

# %%
Input_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]

item = input("Enter the item to remove: ")
print(item)
Input_list.remove(item)
print(Input_list)
# Out:
# python
# ['amit', 'learning', 'machine learning', 'data science', 'deep learning']

# %%
my_list = [1, 2, 3]
index_of_2 = my_list.index(2)
print(index_of_2)
# Out:
# 1

# %%
my_list = [1, 2, 3, 2, 4, 2]
count_of_2 = my_list.count(2)
print(count_of_2)
# Out:
# 3

# %%
x={1,2,3}
type(x)
# Out:
# set

# %%
x2={1:"ahmed"}
type(x2)
# Out:
# dict

# %%
A={1,2,3}
B={3,4,5}
print(A|B)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(A.intersection(B))
# Out:
# {3}

# %%
dict_1 = {"key1": 12.4, "key2": 5}
dict_1["key1"] = "Depi"
dict_1
# Out:
# {'key1': 'Depi', 'key2': 5}

# %%
num_1 = float(input("enter first number: "))
num_2 = float(input("enter second number: "))

print(f"summation: {num_1 + num_2:.2f}")
print(f"subtraction: {num_1 - num_2:.2f}")
print(f"multiplication: {num_1 * num_2:.2f}")
print(f"division: {num_1 / num_2:.2f}")
# Out:
# summation: 70.00
# subtraction: 30.00
# multiplication: 1000.00
# division: 2.50

# %%
score = float(input("Enter your score: "))

if score >= 90:
    print(" A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")
# Out:
#  A
