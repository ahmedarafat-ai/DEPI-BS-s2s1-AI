# %%
print("Ahmed")
# Out:
# Ahmed

# %%
x="depi-r5"
print("my name is{0}, my age is{1}". format("amit",25))
# Out:
# my name isamit, my age is25

# %%
name=input("Name: ")
age= input("Age: ")
course=input("course:")

print("Name",name)
print("Age",age)
print("course",course)

# %%
your_ name ="amit learning"
your_age=25
course_name="machine learning and AI disploma"
print(output_text)
